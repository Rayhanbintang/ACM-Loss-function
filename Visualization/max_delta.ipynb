# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

df = pd.read_excel('master_data.xlsx')
df.columns
# Out:
# Index(['dice_AC_L1', 'hd_AC_L1', 'assd_AC_L1', 'vol_AC_L1', 'vol_err_AC_L1',
#        'dice_AC_L5', 'hd_AC_L5', 'assd_AC_L5', 'vol_AC_L5', 'vol_err_AC_L5',
#        'dice_AC_L10', 'hd_AC_L10', 'assd_AC_L10', 'vol_AC_L10',
#        'vol_err_AC_L10', 'dice_DICE', 'hd_DICE', 'assd_DICE', 'vol_DICE',
#        'vol_err_DICE', 'dice_DOF', 'hd_DOF', 'assd_DOF', 'vol_DOF',
#        'vol_err_DOF', 'dice_wxent', 'hd_wxent', 'assd_wxent', 'vol_wxent',
#        'vol_err_wxent', 'dice_xent', 'hd_xent', 'assd_xent', 'vol_xent',
#        'vol_err_xent', 'phase', 'struc', 'filename'],
#       dtype='object')

# %%
df_dice = df.loc[:, ['dice_AC_L10','dice_DICE','dice_DOF','dice_wxent','dice_xent']]

# %%
df_dice.diff(axis=1)
# Out:
#      dice_AC_L10  dice_DICE  dice_DOF  dice_wxent  dice_xent
# 0            NaN   0.001760 -0.004421    0.004012  -0.000419
# 1            NaN  -0.044714  0.037649    0.005852   0.020416
# 2            NaN  -0.026921  0.025679   -0.008686  -0.006559
# 3            NaN  -0.004236 -0.004369    0.006127  -0.004018
# 4            NaN  -0.095195  0.033868    0.045551   0.045082
# 5            NaN  -0.017590  0.017759   -0.000294  -0.013634
# 6            NaN  -0.002597 -0.000202   -0.000818  -0.000360
# 7            NaN  -0.005089  0.000665   -0.021465   0.009846
# 8            NaN  -0.011027 -0.007056    0.004211  -0.014171
# 9            NaN  -0.001656  0.001116    0.004636  -0.003496
# 10           NaN  -0.038662  0.004833   -0.021651   0.078043
# 11           NaN  -0.011159 -0.002817    0.007336  -0.010869
# 12           NaN   0.005824 -0.005413    0.006000  -0.006138
# 13           NaN  -0.006859 -0.005502    0.019042  -0.010503
# ...
